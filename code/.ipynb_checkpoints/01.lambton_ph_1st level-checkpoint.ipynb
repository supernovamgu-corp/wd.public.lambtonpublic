# %%
#import necessary packages
import platform
import os
import sys
import time
#for managing the data
import pandas as pd

#install !pip install webdriver-manager
#webdrivers
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup
# Out:
# /Users/mike/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/mike/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
#data prefix for output data
yearmonth = "202404"

# %%
#open web driver
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
driver.get("https://www.google.com")

# %%
#url
base_url_list = \
[
    ['DineSafe Lambton',"https://reports.lambtonpublichealth.ca/DineSafeLambton/Table", ['Community','Facility Name','Colour Posting','Last Inspection Date','Site Address'] ],
    ['PersonalServiceSettings',"https://reports.lambtonpublichealth.ca/PersonalServiceSettings/Table", ['Community','Facility Name','Last Inspection Date','Site Address',]],
    ['Licensed Child Care',"https://reports.lambtonpublichealth.ca/LicensedChildCare/Table", ['Facility Name','Site Address','Last Inspection Date']],
    ['RecreationalCamps',"https://reports.lambtonpublichealth.ca/RecreationalCamps/Table",['Facility Name','Site Address','Last Inspection Date']],
    ['temporarily_closed',"http://disclosure.algomapublichealth.com/Portal/Closure",['Facility Name','Site Address','Community','Program Area','Closed Date','Reason','Reopen Date']],
    ['tickets_orders',"http://disclosure.algomapublichealth.com/Portal/Enforcements",['Facility Name','Site Address','Type','Offense','Outcome','Offense Date','Resolved Date']],
]

# %%
base_url_list
# Out:
# [['food',
#   'http://disclosure.algomapublichealth.com/Portal/Food/Table',
#   ['Facility Name', 'Site Address', 'Last Inspection Date', 'Facility Type']],
#  ['beauty_body_child_care',
#   'http://disclosure.algomapublichealth.com/Portal/BeautyBodyArtAndChildCareServices/Table',
#   ['Facility Name', 'Site Address', 'Last Inspection Date', 'Facility Type']],
#  ['pools_spas',
#   'http://disclosure.algomapublichealth.com/Portal/PoolsSpas/Table',
#   ['Facility Name', 'Site Address', 'Last Inspection Date']],
#  ['small_drinking_water',
#   'http://disclosure.algomapublichealth.com/Portal/SmallDrinkingWaterSystems/Table',
#   ['Facility Name', 'Site Address', 'Last Inspection Date']],
#  ['temporarily_closed',
#   'http://disclosure.algomapublichealth.com/Portal/Closure',
#   ['Facility Name',
#    'Site Address',
#    'Community',
#    'Program Area',
#    'Closed Date',
#    'Reason',
#    'Reopen Date']],
#  ['tickets_orders',
#   'http://disclosure.algomapublichealth.com/Portal/Enforcements',
#   ['Facility Name',
#    'Site Address',
#    'Type',
#    'Offense',
#    'Outcome',
#    'Offense Date',
#    'Resolved Date']]]

# %%
#place holder for final dataframe list
df_list = []

for u in base_url_list:
    category = u[0]
    base_url = u[1]
    columns  = u[2]

    #load main landing page
    driver.get(base_url)
    
    try:
        #find disclaimer button
        disclamer_btn = driver.find_element(by='name', value="AcceptDisclaimerButton")

        #click the disclaimer button to move to the data page
        disclamer_btn.click()
    except:
        pass
    
    # We will loop through until there's no next page button on the webpage
    #find next page button
    last_page = False

    while last_page==False:
        try:
            next_btn = driver.find_element(By.CLASS_NAME, value="next-page-link")
        except:
            last_page = True


        #place holder for extracted data
        data_url_list = []

        #locate each table rows
        data_rows = driver.find_elements(By.CLASS_NAME, value="hovereffect")

        for row in data_rows:
            data_url_list.append( row.get_attribute("onclick") )

        #convert html table into dataframe
        df = pd.read_html(driver.page_source)
        df = df[0]
        

        #rename columns for clean up
        df.columns = columns
        
        #append url column and category column
        df['url'] = data_url_list
        df['category'] = category

        #put aside resulting table
        df_list.append(df)

        if last_page==True:
            break
        #move to the next page
        next_btn.click()

# %%
final_df = pd.concat(df_list)

# %%
final_df
# Out:
#                                         Facility Name  \
# 0   Thyne's Family Bakery & the Cat-Urday Cafe - B...
# 1                          17 Restaurant - Restaurant
# 2            17E Trading Post - Convenience / Variety
# 3   40 Below Freeze Dried Snacks - Home Based Food...
# 4                             75 Pies - Food Take Out
# ..                                                ...
# 2                           Elliot Lake Municipal Spa
# 3                   Elliot Lake Municipal Wading Pool
# 4                             Market Mall Barber Shop
# 0                     Esso (McDougall Energy) #319103
# 1                                         RJ's Market
#
#                                          Site Address Last Inspection Date  \
# 0                 177 Gore Street  Sault Ste Marie ON          20-Sep-2023
# 1             2-Woodward Ave.  Blind River ON P0R 1B0          06-Dec-2023
# 2             6999 Highway 17 E  Desbarats ON P0R 1E0          04-Mar-2024
# 3                                     no site address          09-Jun-2023
# 4   124 Bruce Street  Sault Ste. Marie Ontario P6A...          10-Aug-2023
# ..                                                ...                  ...
# 2      301 Mississauga Avenue  Elliot Lake ON P5A 1E8                  NaN
# 3                  301 Missisauga Ave  Elliot Lake ON                  NaN
# 4      65AB-275 Second Line West  Sault Ste. Marie ON                  NaN
# 0   207 Wellington Street W  Sault Ste. Marie ON P...                  NaN
# 1    238 Wellington St W  Sault Ste. Marie ON P6A 1H8                  NaN
#
#                  Facility Type  \
# 0         Baked Goods - Retail
# 1                   Restaurant
# 2        Convenience / Variety
# 3   Home Based Food Inspection
# 4                Food Take Out
# ..                         ...
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 0                          NaN
# 1                          NaN
#
#                                                   url            category  \
# 0   location.href = '/Portal/Facility/Details/685a...                food
# 1   location.href = '/Portal/Facility/Details/d186...                food
# 2   location.href = '/Portal/Facility/Details/c1fe...                food
# 3   location.href = '/Portal/Facility/Details/89b7...                food
# 4   location.href = '/Portal/Facility/Details/14c6...                food
# ..                                                ...                 ...
# 2   location.href = '/Portal/Facility/Details/944a...  temporarily_closed
# 3   location.href = '/Portal/Facility/Details/5799...  temporarily_closed
# 4   location.href = '/Portal/Facility/Details/a5e8...  temporarily_closed
# 0   location.href = '/Portal/Facility/Details/4a47...      tickets_orders
# 1   location.href = '/Portal/Facility/Details/b2c1...      tickets_orders
#
#                  Community        Program Area  Closed Date  \
# 0                      NaN                 NaN          NaN
# 1                      NaN                 NaN          NaN
# 2                      NaN                 NaN          NaN
# 3                      NaN                 NaN          NaN
# 4                      NaN                 NaN          NaN
# ..                     ...                 ...          ...
# 2    Elliot Lake (City of)  Recreational Water  23-Aug-2023
# 3    Elliot Lake (City of)  Recreational Water  23-Aug-2023
# 4   Sault Ste. Marie (P6A)   Infection Control  16-Feb-2023
# 0                      NaN                 NaN          NaN
# 1                      NaN                 NaN          NaN
#
#                                                Reason  Reopen Date  \
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4                                                 NaN          NaN
# ..                                                ...          ...
# 2                                                 NaN          NaN
# 3                                                 NaN          NaN
# 4   Renovations occurring at mall, facility is clo...          NaN
# 0                                                 NaN          NaN
# 1                                                 NaN          NaN
#
#                    Type                                            Offense  \
# 0                   NaN                                                NaN
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# ..                  ...                                                ...
# 2                   NaN                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN                                                NaN
# 0   Ticket - SFOA, 2017  Supply tobacco to a person who is less than 19...
# 1   Ticket - SFOA, 2017  Supply tobacco to a person who is less than 19...
#
#                   Outcome Offense Date Resolved Date
# 0                     NaN          NaN           NaN
# 1                     NaN          NaN           NaN
# 2                     NaN          NaN           NaN
# 3                     NaN          NaN           NaN
# 4                     NaN          NaN           NaN
# ..                    ...          ...           ...
# 2                     NaN          NaN           NaN
# 3                     NaN          NaN           NaN
# 4                     NaN          NaN           NaN
# 0   Successful Conviction  05-Dec-2019   13-Feb-2020
# 1   Successful Conviction  05-Dec-2018   13-Feb-2020
#
# [1383 rows x 16 columns]

# %%
#serialize the dataset
final_df.to_csv( "../data/{}_1st_table.csv".format(yearmonth) )

# %%
#close webdriver
try:
    driver.close()
except:
    pass
